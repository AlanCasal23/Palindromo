// %% [markdown]
// Palindromo Casal

// %%
String cadena = "Hola Mundo";

String invertir(String cadena) {
    String resultado = "";
for (int i = cadena.length() - 1; i >= 0; i--) {
    resultado += cadena.charAt(i);
}
return resultado;
}

System.out.println(invertir(cadena));

// %% [markdown]
// STRING + string concatena;
//
// string += string concatena y asigna;
//
// string + char transforma el char en string;
//
// string += char concatena;

// %%
String palabra = "radar";
boolean esPalindromo = true;

for (int i = 0; i < palabra.length() / 2; i++) {
    if (palabra.charAt(i) != palabra.charAt(palabra.length() - 1 - i)) {
        esPalindromo = false;
    }
}

System.out.println(esPalindromo);

// %%
String conMayusculas = "La Ruta Nos Aportó Otro Paso Natural";
String todoEnMinusculas = conMayusculas.toLowerCase();
String todoEnMayusculas = conMayusculas.toUpperCase();

System.out.println(todoEnMinusculas);
System.out.println(todoEnMayusculas);
System.out.println(conMayusculas);

String limpiar(String cadena){
    String resultado ="";
cadena = cadena.toLowerCase();
for (int i = 0; i < cadena.length(); i++){
    char c = cadena.charAt(i);

    if (c == 'á') c = 'a';

    else if (c == 'é') c = 'e';
    else if (c == 'í') c = 'i';
    else if (c == 'ó') c = 'o';
    else if (c == 'ú') c = 'u';

    if ((c >= 'a' && c <= 'z') || (c >= '0' && c <= '9')) {
        resultado += c;
    }
}
return resultado;
}

// %%
String limpiar(String cadena) {
    String resultado = "";
cadena = cadena.toLowerCase();

for (int i = 0; i < cadena.length(); i++) {
    char c = cadena.charAt(i);

    if (c == 'á') c = 'a';
    else if (c == 'é') c = 'e';
    else if (c == 'í') c = 'i';
    else if (c == 'ó') c = 'o';
    else if (c == 'ú') c = 'u';

    String caracter = String.valueOf(c);
    if ((c >= 'a' && c <= 'z') || (c >= '0' && c <= '9')) {
        resultado += caracter; 
    }
}
return resultado;
}

System.out.println("Algo, otra cosa".replace(",",""));

// %%
String cadena = "¡Hola, mundo! @Java #Código.";
String aQuitar = " ,./?~!¡@#$%^&*()_+[]{}|;:'\"";
String cadenaNormalizada = cadena.toLowerCase(); 


for (int i = 0; i < aQuitar.length(); i++) {
    cadenaNormalizada = cadenaNormalizada.replace(String.valueOf(aQuitar.charAt(i)), "");
}

String conAcentos    = "áéíó";
String sinAcentos    = "aeiou";

for (int i = 0; i < conAcentos.length(); i++) {
    cadenaNormalizada = cadenaNormalizada.replace(
        String.valueOf(conAcentos.charAt(i)),
        String.valueOf(sinAcentos.charAt(i))
    );
}

System.out.println(cadenaNormalizada);

// %%
String fraseConAcentos = "El pingüino Ramón comió ñame en el camión de Asunción.";
String fraseSinAcentos = fraseConAcentos;
String conAcentos = "áéíóúüñÁÉÍÓÚÜÑ";
String sinAcentos = "aeiouunAEIOUUN";

for (int i = 0; i < conAcentos.length(); i++) {
    fraseSinAcentos = fraseSinAcentos.replace(
        String.valueOf(conAcentos.charAt(i)),
        String.valueOf(sinAcentos.charAt(i))
    );
}

System.out.println(fraseSinAcentos);

// %%
String aMinusculas(String frase) {
    return frase.toLowerCase();
}
String sinEspaciosNiSignos(String frase) {
    String aQuitar = " ,./?~!¡¿@#$%^&*()_+[]{}|;:'\"";
    for (int i = 0; i < aQuitar.length(); i++) {
        frase = frase.replace(String.valueOf(aQuitar.charAt(i)), "");
    }
    return frase;
}
String sinEspaciosNiSignos(String frase) {
    String aQuitar = " ,./?~!¡¿@#$%^&*()_+[]{}|;:'\"";
    for (int i = 0; i < aQuitar.length(); i++) {
        frase = frase.replace(String.valueOf(aQuitar.charAt(i)), "");
    }
    return frase;
}

String sinAcentos(String frase) {
    String conAcentos = "áéíóúüñÁÉÍÓÚÜÑ";
    String sinAcento  = "aeiouunAEIOUUN";
    for (int i = 0; i < conAcentos.length(); i++) {
        frase = frase.replace(
            String.valueOf(conAcentos.charAt(i)),
            String.valueOf(sinAcento.charAt(i))
        );
    }
    return frase;
}

String normalizar(String frase) {
    frase = aMinusculas(frase);
    frase = sinEspaciosNiSignos(frase);
    frase = sinAcentos(frase);
    return frase;
}

    boolean esPalindromo(String frase){
           frase = normalizar(frase);
    for (int i = 0; i < frase.length() / 2; i++) {
        if (frase.charAt(i) != frase.charAt(frase.length() - 1 - i)) {
            return false;
        }
    }
    return true;
    }

String poema = "'Amor azul' Ramera, de todo te di. Mariposa colosal, sí, yo de todo te di. Poda la rosa, Venus. El átomo como tal es un evasor alado. Pide, todo te doy: isla, sol, ocaso, pirámide. Todo te daré: mar, luz, aroma.";

system.out.printIn(esPalindromo(poema));
